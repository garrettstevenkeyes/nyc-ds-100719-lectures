# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#Load our dataframe account for the index columns
df = pd.read_csv('case_study.csv',index_col=0)
# Out:
# //anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (171) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Quickly check to see the size of our DF, both rows and columns
df.head()
# Out:
#        _STATE  FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 49938     9.0     5.0  5172017       5    17   2017    1200.0  2017000001
# 49939     9.0     2.0  2142017       2    14   2017    1200.0  2017000002
# 49940     9.0     1.0  1292017       1    29   2017    1200.0  2017000003
# 49941     9.0     7.0  9112017       9    11   2017    1200.0  2017000004
# 49942     9.0     5.0  7182017       7    18   2017    1200.0  2017000005
#
#                _PSU  CTELENM1  ...  _PA300R2  _PA30021  _PASTRNG  _PAREC1  \
# 49938  2.017000e+09       NaN  ...       2.0       2.0       2.0      4.0
# 49939  2.017000e+09       NaN  ...       1.0       1.0       1.0      1.0
# 49940  2.017000e+09       NaN  ...       3.0       2.0       1.0      3.0
# 49941  2.017000e+09       NaN  ...       2.0       2.0       2.0      2.0
# 49942  2.017000e+09       NaN  ...       2.0       2.0       1.0      1.0
#
#        _PASTAE1  _RFSEAT2  _RFSEAT3  _FLSHOT6  _PNEUMO2  _AIDTST3
# ...

# %%
df.shape
# Out:
# (34545, 358)

# %% [markdown]
# ## Subset your dataframe to only include the states in the tri-state area (NJ, CT, NY)

# %%
tristate = [9,34,36]
# your code here
df = df[df['_STATE'].isin(tristate)] 
df
#use .isin() if we have a long list of values we want to check against
# Out:
#         _STATE  FMONTH     IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 49938      9.0     5.0   5172017       5    17   2017    1200.0  2017000001
# 49939      9.0     2.0   2142017       2    14   2017    1200.0  2017000002
# 49940      9.0     1.0   1292017       1    29   2017    1200.0  2017000003
# 49941      9.0     7.0   9112017       9    11   2017    1200.0  2017000004
# 49942      9.0     5.0   7182017       7    18   2017    1200.0  2017000005
# 49943      9.0     1.0   1192017       1    19   2017    1100.0  2017000006
# 49944      9.0     1.0   2032017       2     3   2017    1100.0  2017000007
# 49945      9.0     1.0   2012017       2     1   2017    1100.0  2017000008
# 49946      9.0     1.0   1262017       1    26   2017    1100.0  2017000009
# 49947      9.0     1.0   1192017       1    19   2017    1100.0  2017000010
# 49948      9.0     1.0   1242017       1    24   2017    1100.0  2017000011
# ...

# %% [markdown]
# Now check to see how large our subset df.

# %%
# your code here

# %% [markdown]
# **PHYSHLTH** is the column we are interested in for this analysis, so let's start to investigate the column. Since we have a data cookbook, a.k.a. data dictionary) we want to start there before looking at the code.

# %%
df['PHYSHLTH'].describe()
# Out:
# count    34545.000000
# mean        60.213403
# std         37.504566
# min          1.000000
# 25%         15.000000
# 50%         88.000000
# 75%         88.000000
# max         99.000000
# Name: PHYSHLTH, dtype: float64

# %% [markdown]
# ## 1. Handle the non-normal values
#
# As you can see from the data dictionary, there are a number of responses that are coded with values that could throw off our descriptive statistics.  Let's clean up by mapping the responses to a more appropriate value, and handling any missing values.

# %%
#your code here

#reassign where the value of Physhlth = 0

zero_dict = {88:0,
            77: np.nan,
            99: np.nan}

df['PHYSHLTH'] = df['PHYSHLTH'].replace(zero_dict)

# %%
df['PHYSHLTH'].describe()
# Out:
# count    33747.000000
# mean         4.085341
# std          8.513293
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          3.000000
# max         30.000000
# Name: PHYSHLTH, dtype: float64

# %% [markdown]
# ## 2. Generate the descriptive statistics
#
# Now that our target variable is cleaned up lets calculate the descriptive statistics, generate a graph that quickly shows those statistics, and generate a gprah shows the histogram of the data.

# %%
# descriptive statistics
df['PHYSHLTH'].describe()
# Out:
# count    33747.000000
# mean         4.085341
# std          8.513293
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          3.000000
# max         30.000000
# Name: PHYSHLTH, dtype: float64

# %%
# graphic showing those descriptive stats
health_description =df['PHYSHLTH']
health_description.plot.box()
#doesnt make sense, come back

# %%
# graphic showing the distribution of data
health_description.plot.hist(bins=30,ec='black')

# %% [markdown]
# ## 3. Generate a graphic that compares the average number of sick days for each state.

# %%
# code to calculate the average number of sick days by state
tri_state_ave_mean = pd.DataFrame(df.groupby('_STATE')['PHYSHLTH'].mean())
tri_state_ave_mean
# Out:
#         PHYSHLTH
# _STATE
# 9.0     3.688562
# 34.0    4.380957
# 36.0    4.148030

# %%
# code to graph those averages using matplotlib
tri_state_ave_mean.plot.bar()

# %% [markdown]
# ## 4. Turn the number of sick days into a classification of of chronically sick people.
#
# Chronically sick people account for a significant proportion of the costs for health insurers. If we can identify what leads people to be chronically sick, we can address them with specific treatments.

# %%
# code to create new colum for chronically sick
#chronically sick people can be defined as people in the 80th percentile and higher

df['chron_sick'] = df['PHYSHLTH'] >= 10
chron_sick = len(df[df['chron_sick'] == True])
tot_pop = len(df['PHYSHLTH'])
p_sick = round((chron_sick/tot_pop) * 100, 2) 

print(f'{p_sick} % of people are chronically sick!')
# Out:
# 14.7 % of people are chronically sick!

# %% [markdown]
# ## 5. Create a graphic that compares the percentage of people labeled as 'sick' in each state.

# %%
# code to calculate averages per state
state_df = df['_STATE'].reset_index()
sick_df = df['chron_sick'].reset_index()
sick_df
state_df
sick_by_state = sick_df.merge(state_df, on = 'index', how = 'right')
sick_by_state
# Out:
#         index  chron_sick  _STATE
# 0       49938       False     9.0
# 1       49939       False     9.0
# 2       49940       False     9.0
# 3       49941       False     9.0
# 4       49942       False     9.0
# 5       49943       False     9.0
# 6       49944       False     9.0
# 7       49945       False     9.0
# 8       49946        True     9.0
# 9       49947       False     9.0
# 10      49948       False     9.0
# 11      49949       False     9.0
# 12      49950       False     9.0
# 13      49951       False     9.0
# 14      49952       False     9.0
# 15      49953       False     9.0
# 16      49954       False     9.0
# 17      49955        True     9.0
# 18      49956       False     9.0
# 19      49957       False     9.0
# 20      49958       False     9.0
# 21      49959       False     9.0
# 22      49960       False     9.0
# 23      49961       False     9.0
# 24      49962       False     9.0
# 25      49963       False     9.0
# ...

# %%
# create graphic to compare chronically sick by state

#connecticut sick 
conn_sick = len(df[(df['_STATE'] == 9) & (df['chron_sick'] == True)])   
conn_tot = len(df['_STATE'] == 9)
pct_conn_sick = round(conn_sick/conn_tot * 100, 2)

#new jersey sick
nj_sick = len(df[(df['_STATE'] == 34) & (df['chron_sick'] == True)])
nj_tot = len(df['_STATE'] == 34)
pct_nj_sick = round(nj_sick/nj_tot * 100, 2)

# #NY sick 
ny_sick = len(df[(df['_STATE'] == 36) & (df['chron_sick'] == True)])
ny_tot = len(df['_STATE'] == 36)
pct_ny_sick = round(ny_sick/ny_tot * 100, 2)

plt.bar(['Connecticut Sick', 'NJ Sick', 'NY Sick'],[pct_conn_sick,pct_nj_sick,pct_ny_sick])
plt.ylabel('Percentage Chronically Sick')
plt.title('Which state has the most chronic illness?');

# %% [markdown]
# ## 6. Independent Variables (categorical)
#
# Let's take the column `SMOKDAY2` and start to prepare it so that we can see how it is possibly correlated to `PHYSHLTH`.
#
# 1. Clean up the values.
# 2. Calculate the descriptive statistics of the variable.
# 3. Generate a histogram for the variable.
# 4. Generate graphics that show how the responses to this variable might differ by state.
# 5. Generate a graphic that compares the physical health of the different groups of 'smokers'.

# %%
#1
smoker_stats = df['SMOKDAY2'].value_counts(dropna=True)

#2 
smoker_stats.describe()

#3
pd.DataFrame(smoker_stats)
smokers = pd.DataFrame(smoker_stats)
smokers.plot(kind = 'bar')
plt.xlabel('Days smoking per week')
plt.ylabel('Number of responses')

#4
smokers_by_state = df.groupby('_STATE')['SMOKDAY2'].value_counts()
smokers_by_state.plot.bar().set_title('Smoking rate by state')
plt.xlabel('Smoking rates by state')
plt.ylabel('Number of responses')
plt.grid()

#5

phys_health_comp = df.groupby('SMOKDAY2')['chron_sick'].value_counts()
phys_health_comp.plot.bar()
plt.xlabel('Sickness rate grouped by smoking frequency')
plt.ylabel('Responses');

# %% [markdown]
# ## 7. Independent Variables (continuous):
#
# Now let's look at a continuous variable (ALCDAY5) and see how that might impact a person's health.
#
# 1. Clean up the values.
# 2. Calculate the descriptive statistics of the variable.
# 3. Generate a histogram for the variable.
# 4. Generate graphics that show how the responses to this variable might differ by state.
# 5. Calculate the correlation coefficient between `PHYSHLTH` and `ALCDAY5`.
# 5. Generate a graphic that shows the possible relationship between `PHYSHLTH` and `ALCDAY5`.

# %%
# your code here

#1 need to get rid of the blank, get rid of the 999 which is refused, get rid of the BLANK 
alc_value_counts = df['ALCDAY5'].value_counts(dropna=True)
alc_value_counts_clean = (df[(df['ALCDAY5'] != 999) & (df['ALCDAY5'] != 'BLANK')]).reset_index()
#check answer
#alc_value_counts_clean['ALCDAY5'].value_counts()

#alc_value_counts_clean
#pd.DataFrame((alc_value_counts_clean['ALCDAY5'] >= 101) & (alc_value_counts_clean['ALCDAY5'] <= 107)) 


#take week column and mutiply the week people by 4.28 to get the month
#week_answers = pd.DataFrame((alc_value_counts_clean['ALCDAY5'] >= 101) & (alc_value_counts_clean['ALCDAY5'] <= 107))   


#week_data = df['week_answers'].reset_index()
#week_data


#combine with the month column to make new data frame
#all_week_data = alc_value_counts_clean.merge(week_data)

# %%
alc_value_counts3['ALCDAY5'].value_counts()
# Out:
# 888.0    13043
# 201.0     3027
# 202.0     2324
# 101.0     1596
# 203.0     1350
# 102.0     1232
# 230.0     1164
# 205.0     1156
# 204.0     1144
# 210.0      840
# 103.0      782
# 107.0      710
# 220.0      650
# 215.0      590
# 206.0      389
# 104.0      386
# 208.0      369
# 105.0      352
# 207.0      278
# 225.0      265
# 777.0      225
# 999.0      201
# 212.0      144
# 106.0      109
# 228.0       56
# 214.0       53
# 229.0       31
# 209.0       28
# 227.0       24
# 218.0       19
# 216.0       15
# 226.0       15
# 224.0       14
# 222.0       13
# 221.0       13
# 213.0       11
# 211.0       10
# 217.0        7
# 223.0        2
# 219.0        1
# Name: ALCDAY5, dtype: int64

# %% [markdown]
# ## 8. Additional variables: Choose two additional survey items you would like to investigate do steps  6 or 7 for those variables.

# %%
# Out:
# 49938    101.0
# 49939    230.0
# 49940    888.0
# 49941    103.0
# 49942    101.0
# Name: ALCDAY5, dtype: float64

# %% [markdown]
# ## 9. Based on your initial data exploration, what are some hypotheses of what affects a person's health that you would like to further investigate?

# %% [markdown]
# Type out your initial hyptotheses below:
#
# 1.
#
# 2.
#
# 3.

# %% [markdown]
# ## Bonus: Create some cool graphics.
